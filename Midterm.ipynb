# %% [markdown]
# # Midterm

# %% [markdown]
# ### Question 1

# %% [markdown]
# In Robert McCloskey’s book Make Way for Ducklings, the names of the ducklings are Jack, Kack, Lack, Mack, Nack, Ouack, Pack, and Quack. This loop outputs these names in order:
#
#     prefixes = 'JKLMNOPQ'
#     suffix = 'ack'
#     for letter in prefixes:
#         print letter + suffix
#
#     The output is:
#     Jack
#     Kack
#     Lack
#     Mack
#     Nack
#     Oack
#     Pack
#     Qack
#
# Of course, that’s not quite right because “Ouack” and “Quack” are misspelled.
# Modify the program to fix this error.

# %%
#Implement your solution here
#Solution: Iterate through list instead of string
prefixes = ['J','K','L','M','N','Ou','P','Qu'] 
suffix = 'ack'
for letter in prefixes: 
    print letter + suffix
# Out:
# Jack
# Kack
# Lack
# Mack
# Nack
# Ouack
# Pack
# Quack

# %% [markdown]
# ### Question 2

# %% [markdown]
# Use ipythonblocks to create an 8x8 grid with the first initial of your last name embedded in it in a different color. Use slices and/or loops to set the values rather than setting each block by hand.

# %%
#Implement your solution here
from ipythonblocks import BlockGrid

Grid = BlockGrid(8,8,(0,0,0))

column_number = 1
for row_number in range(1,7):
    Grid[row_number, column_number] = (0,255,255)
    
column_number = 6
for row_number in range(1,7):
    Grid[row_number, column_number] = (0,255,255)

#Color diagonally
for row_number in range(2,6):
    for column_number in range(2,6):
        if column_number == row_number:
            Grid[row_number, column_number] = (0,255,255)

Grid.show()
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks63aa81b2-bf69-499b-b768-4c1cb3689c88 td {border: 1px solid white;}</style><table id="blocks63aa81b2-bf69-499b-b768-4c1cb3689c88" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title=
# ...

# %% [markdown]
# ### Question 3

# %% [markdown]
# "99 Bottles of Beer" is a traditional song in the United States and Canada. It is popular to sing on long trips, as it has a very repetitive format which is easy to memorize, and can take a long time to sing. The song's simple lyrics are as follows:
#
#     99 bottles of beer on the wall, 99 bottles of beer.
#     Take one down, pass it around, 98 bottles of beer on the wall.
#
# The same verse is repeated, each time with one fewer bottle. The song is completed when the singer or singers reach zero.
# Your task here is to write a program capable of generating all the verses of the song.

# %%
n = 1

while n < 100:
    if n < 99:
        print '%s bottles of beer on the wall, %s bottles of beer.' %(100 - n, 100 - n)
        n += 1
        print 'Take one down, pass it around, %s bottles of beer on the wall.' %(100 - n)
        print 
#Change "bottles" to "bottle" for last loop
    else:
        print '%s bottle of beer on the wall, %s bottle of beer.' %(100 - n, 100 - n)
        n += 1
        print 'Take one down, pass it around, %s bottles of beer on the wall.' %(100 - n)
        print
# Out:
# 99 bottles of beer on the wall, 99 bottles of beer.
# Take one down, pass it around, 98 bottles of beer on the wall.
#
# 98 bottles of beer on the wall, 98 bottles of beer.
# Take one down, pass it around, 97 bottles of beer on the wall.
#
# 97 bottles of beer on the wall, 97 bottles of beer.
# Take one down, pass it around, 96 bottles of beer on the wall.
#
# 96 bottles of beer on the wall, 96 bottles of beer.
# Take one down, pass it around, 95 bottles of beer on the wall.
#
# 95 bottles of beer on the wall, 95 bottles of beer.
# Take one down, pass it around, 94 bottles of beer on the wall.
#
# 94 bottles of beer on the wall, 94 bottles of beer.
# Take one down, pass it around, 93 bottles of beer on the wall.
#
# 93 bottles of beer on the wall, 93 bottles of beer.
# Take one down, pass it around, 92 bottles of beer on the wall.
#
# 92 bottles of beer on the wall, 92 bottles of beer.
# Take one down, pass it around, 91 bottles of beer on the wall.
#
# ...

# %% [markdown]
# ### Question 4

# %% [markdown]
# Plot a simple graph of a sine function in the range 0 to 3 with a step size of 0.1.
#
#     Make the line red.
#     Add green diamond-shaped markers with size of 7.
#     Include legible axis labels.
#     Add a legend and a grid to the plot.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Range is from 0 to 3 with 31 values, resulting in a step size of 0.1
x = np.linspace(0, 3.0, 3.1/.1)

#Make the line red.
#Add green diamond-shaped markers with size of 7.
y = np.sin(x)
plt.plot(x,y,'gD', x,y,'red', ms = 7,label="sine")

#Add a legend and a grid to the plot
plt.grid()
plt.legend(loc = 'upper left')

#Include legible axis labels
plt.xlabel('X-Values',size = 30)
plt.ylabel('Y-values',size = 30)
plt.show()

# %% [markdown]
# ### Question 5

# %% [markdown]
# Create a 100x5 NumPy array called arr of random floating point numbers between 10.7 and 36.2.
#
#     Write the array to a file called numbers.txt as 5 columns separated by 2 spaces and formatted with 3 places after the decimal.
#     Include a 3-line header that lists the date and time on line 2 (hint: try !date).
#     Show the first 10 lines of the file using the !head command.
#
# Read the data back in from the file to a new floating point NumPy array called arr2 and use a slice to print the first ten lines of the array.

# %%
#Create 100x5 array
arr = np.random.uniform(10.7,36.2,500)
arr = arr.reshape(100,5)

#Write to numbers.txt with data separated by 2 spaces
#Date and time
a = !Date
np.savetxt('numbers.txt', arr, fmt='%6.3f',delimiter='  ', header='\n%s\n'%(a))

#Show first 10 lines
# !head -10 numbers.txt

a = open('numbers.txt')
arr2 = np.load('numbers.txt')
print arr2[:11]
# Out:
# #
# # ['Tue Apr 29 13:59:13 PDT 2014']
# #
# 11.646  10.905  22.650  27.196  32.517
# 32.064  32.054  29.987  31.409  12.782
# 21.015  25.275  30.624  13.621  32.616
# 31.011  12.059  23.543  26.397  14.669
# 30.185  24.877  16.327  29.232  21.897
# 25.495  23.642  14.008  22.555  35.009
# 31.607  15.461  35.392  22.694  36.053
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-171-f439860cd9a4> in <module>()
#      12
#      13 a = open('numbers.txt')
# ---> 14 arr2 = np.load('numbers.txt')
#      15 print arr2[:11]
#
# /Applications/anaconda/lib/python2.7/site-packages/numpy/lib/npyio.pyc in load(file, mmap_mode)
#     396             except:
#     397                 raise IOError(
# --> 398                     "Failed to interpret file %s as a pickle" % repr(file))
#     399     finally:
#     400         if own_fid:
#
# ...
